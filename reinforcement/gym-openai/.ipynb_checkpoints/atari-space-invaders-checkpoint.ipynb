# %%
import gym

# %%
env = gym.make('SpaceInvaders-v0')
env.reset()
env.render()
# Out:
# [2017-07-25 16:22:55,087] Making new env: SpaceInvaders-v0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Volumes/Toshiba/anaconda/envs/deeplearning/lib/python3.6/site-packages/gym/envs/atari/atari_env.py in <module>()
#       8 try:
# ----> 9     import atari_py
#      10 except ImportError as e:
#
# ModuleNotFoundError: No module named 'atari_py'
#
# During handling of the above exception, another exception occurred:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# <ipython-input-2-690fd8bd0a8a> in <module>()
#       1
# ----> 2 env = gym.make('SpaceInvaders-v0')
#       3 env.reset()
#       4 env.render()
#
# /Volumes/Toshiba/anaconda/envs/deeplearning/lib/python3.6/site-packages/gym/envs/registration.py in make(id)
#     159
#     160 def make(id):
# --> 161     return registry.make(id)
#     162
#     163 def spec(id):
#
# ...
